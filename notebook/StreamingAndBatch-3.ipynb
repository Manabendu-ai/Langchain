# %% [markdown]
# ### Streaming and Batch

# %% [markdown]
# #### Streaming

# %% [markdown]
# `Most models can stream their output content while being generated. By displaying output progressively,
# streaming significantly improves user experience, particularly for longer responses. Calling stream() returns an iterator that yields
# output chunks as they are produced. You can use a Loop to process each chunk in real-time:`

# %%
import os
from langchain_groq import ChatGroq

os.environ["groq_api_key"] = os.getenv("GROQ_API_KEY")
model = ChatGroq(
    model = "llama-3.3-70b-versatile"
)

# %%
for chunks in model.stream("Why do parrot's have colorful feathers?"):
    print(chunks.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| for| several| reasons|.| Here| are| some| possible| explanations|:
#
# |1|.| **|Communication| and| Social| Sign|aling|**:| Bright| colors| can| help| par|rots| communicate| with| each| other|,| signal| their| sex|,| age|,| and| social| status|.| Different| colors| can| convey| different| messages|,| such| as| attracting| a| mate|,| warning| off| rivals|,| or| signaling| dominance|.
# |2|.| **|Cam|ouflage| and| Mim|ic|ry|**:| While| it| may| seem| counter|int|uitive|,| some| par|rots|'| bright| colors| can| actually| help| them| blend| in| with| their| surroundings|.| For| example|,| the| blue| and| yellow| feathers| of| the| blue|-and|-yellow| mac|aw| can| help| it| blend| in| with| the| bright| flowers| and| foliage| of| its| tropical| habitat|.
# ...

# %% [markdown]
# ### Batch

# %% [markdown]
# `Batching is the collection of independent requests to a model that can significantly improve performance and reduce cost,
#  as the processing can be done in parallel.`

# %%
responses = model.batch([
    "What is the type of engine used in BMW M4",
    "What was the primary motivation behind Java?",
    "What is a neural network?"
], 
config={
    "max_concurrency" : 5
}
)

for response in responses:
    print(response.content)
# Out:
# The BMW M4 is a high-performance version of the BMW 4 Series, and it is equipped with a variety of engines depending on the model year and generation. Here are some of the most common engines used in the BMW M4:
#
# * S55B30 engine (2014-2018): This is a 3.0-liter twin-turbo inline-6 engine that produces 425 horsepower and 406 lb-ft of torque.
# * S58B30 engine (2019-present): This is a 3.0-liter twin-turbo inline-6 engine that produces 473 horsepower and 406 lb-ft of torque in the standard M4, and 503 horsepower and 479 lb-ft of torque in the M4 Competition model.
#
# Both of these engines are inline-6 engines, which is a traditional configuration for BMW M cars. They feature a combination of turbocharging, direct fuel injection, and variable valve timing to produce high power and torque outputs. The engines are also paired with a range of transmissions, including a 6-speed manual and an 8-speed automatic with paddle shifters.
# ...
