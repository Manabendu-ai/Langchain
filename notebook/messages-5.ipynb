# %% [markdown]
# ### Messages

# %% [markdown]
# ##### messages are fundamental unit of context for models in LangChain. They represent the input and output of the models, carrying both the content and metadata needed to represent the state of a conversation when interacting with an LLM. Messages are the objects that contain:
# * Role - Identifies the message type(e.g system, user)
# * Content - Represents the actual content of the message.
# * MetaData - Optional fields such as response information, message IDs, and token usage

# %%
import os
from langchain_groq import ChatGroq

model = ChatGroq(
    model = "llama-3.3-70b-versatile"
)

# %%
model.invoke("Please tell me more about Quantum Computing?")
# Out:
# AIMessage(content="Quantum Computing is a revolutionary technology that has the potential to change the way we process information. Here's a comprehensive overview:\n\n**What is Quantum Computing?**\n\nQuantum Computing is a type of computing that uses the principles of quantum mechanics to perform calculations and operations on data. Unlike classical computers, which use bits (0s and 1s) to process information, quantum computers use quantum bits or qubits. Qubits can exist in multiple states simultaneously, allowing for exponentially faster processing of complex calculations.\n\n**Key Principles of Quantum Computing:**\n\n1. **Superposition**: Qubits can exist in multiple states (0, 1, and both 0 and 1 at the same time) simultaneously.\n2. **Entanglement**: Qubits can be connected in such a way that the state of one qubit affects the state of the other, even if they are separated by large distances.\n3. **Quantum interference**: The ability of qubits to interfere with each other, allowing for the cancellation or reinforcement of certain states.\n\n**How does Quantum Computing work?**\n\n1. **Quantum Circuit Model**: Quantum computers use a quantum circuit model, where qubits are connected by quantum gates (operations) that perform calculations.\n2. **Quantum Algorithms**: Quantum algorithms are designed to take advantage of quantum parallelism, allowing for the simultaneous processing of multiple possibilities.\n3. **Measurement**: Quantum computers measure the state of qubits to extract information, which collapses the superposition of states.\n\n**Advantages of Quantum Computing:**\n\n1. **Speedup**: Quantum computers can solve certain problems exponentially faster than classical computers.\n2. **Simulation**: Quantum computers can simulate complex systems, such as molecules and chemical reactions, more accurately than classical computers.\n3. **Optimization**: Quantum computers can optimize complex problems, such as logistics and finance, more efficiently than classical computers.\n\n**Applications of Quantum Computing:**\n\n1. **Cryptography**: Quantum computers can break certain classical encryption algorithms, but they can also be used to create unbreakable quantum encryption methods.\n2. **Optimization**: Quantum computers can be used to optimize complex systems, such as logistics, finance, and energy management.\n3. **Materials Science**: Quantum computers can simulate the behavior of materials at the atomic level, leading to breakthroughs in materials science and engineering.\n4. **Artificial Intelligence**: Quantum computers can be used to speed up machine learning algorithms and improve the performance of AI systems.\n\n**Challenges and Limitations:**\n\n1. **Noise and Error Correction**: Quantum computers are prone to errors due to the noisy nature of quantum systems.\n2. **Scalability**: Currently, quantum computers are small-scale and need to be scaled up to perform complex calculations.\n3. **Quantum Control**: Maintaining control over qubits and quantum gates is essential for reliable operation.\n\n**Current State of Quantum Computing:**\n\n1. **IBM Quantum**: IBM has developed a 53-qubit quantum computer, which is one of the most advanced quantum computers available.\n2. **Google Quantum AI Lab**: Google has developed a 72-qubit quantum computer and is working on a 100-qubit quantum computer.\n3. **Rigetti Computing**: Rigetti Computing is a startup that has developed a 128-qubit quantum computer.\n\n**Future of Quantum Computing:**\n\n1. **Quantum Supremacy**: The development of a quantum computer that can perform calculations beyond the capabilities of classical computers.\n2. **Quantum Error Correction**: The development of robust methods for correcting errors in quantum computers.\n3. **Practical Applications**: The development of practical applications of quantum computing, such as optimization and simulation.\n\nQuantum Computing is a rapidly evolving field, and researchers are making significant progre ...

# %% [markdown]
# ### Text Prompts
# ##### Text Prompts are strings - ideal for straightforward generation tasks, when you don't need to retain conversation history

# %%
model.invoke("What is Langchain?")
# Out:
# AIMessage(content='Langchain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more effectively. It was created to simplify the process of integrating LLMs into various projects, allowing developers to focus on building their applications rather than worrying about the complexities of working with these powerful AI models.\n\nLangchain provides a set of tools and libraries that enable developers to interact with LLMs in a more structured and efficient way. This includes features such as:\n\n1. **LLM wrappers**: Langchain offers wrappers for popular LLMs, making it easier to integrate them into applications.\n2. **Prompt engineering**: The framework includes tools for crafting and optimizing prompts to get the best results from LLMs.\n3. **Chain-of-thought**: Langchain allows developers to create complex, multi-step workflows that leverage the capabilities of LLMs.\n4. **Memory and recall**: The framework provides mechanisms for storing and retrieving information, enabling LLMs to "remember" previous interactions and build upon them.\n\nBy using Langchain, developers can build a wide range of applications, such as:\n\n1. **Chatbots**: Create conversational interfaces that leverage LLMs for more human-like interactions.\n2. **Text generation**: Build applications that generate high-quality text, such as articles, stories, or dialogues.\n3. **Question-answering**: Develop systems that can answer complex questions using the knowledge and understanding of LLMs.\n4. **Creative writing**: Use Langchain to create tools for writers, such as idea generators, plot suggesters, or character developers.\n\nOverall, Langchain aims to democratize access to large language models, making it easier for developers to build innovative applications that push the boundaries of what is possible with AI.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 357, 'prompt_tokens': 40, 'total_tokens': 397, 'completion_time': 1.041965389, 'completion_tokens_details': None, 'prompt_time': 0.00098438, 'prompt_tokens_details': None, 'queue_time': 0.05182988, 'total_time': 1.042949769}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019fc24c-9b1f-7342-9b0d-483136a83fc3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 357, 'total_tokens': 397})

# %% [markdown]
# #### Use Text Prompts when:
# * you have single, standalone request
# * you don't need conversation history
# * you want minimal code complexity

# %% [markdown]
# ### Message Prompts
#
# ##### Alternatively, you can pass in a list of messages to the model by providing a list of message objects.
#
# #### Message types
#
# * System message – Tells the model how to behave and provide context for interactions
# * Human message – Represents user input and interactions with the model
# * AI message – Responses generated by the model, including text content, tool calls, and metadata
# * Tool message – Represents the outputs of tool calls
#
# #### System Message
#
# ##### A SystemMessage represent an initial set of instructions that primes the model’s behavior. You can use a system message to set the tone, define the model’s role, and establish guidelines for responses.
#
# #### Human Message
#
# ##### A HumanMessage represents user input and interactions. They can contain text, images, audio, files, and any other amount of multimodal content.
#
# #### AI Message
#
# ##### An AIMessage represents the output of a model invocation. They can include multimodal data, tool calls, and provider-specific metadata that you can later access.
#
# #### Tool Message
#
# ##### For models that support tool calling, AI messages can contain tool calls. Tool messages are used to pass the results of a single tool execution back to the model.
