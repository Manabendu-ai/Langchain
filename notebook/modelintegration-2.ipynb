# %% [markdown]
# ### Model Integration With Google Gemini and Groq

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ['GEMINI_API_KEY'] = os.getenv("GEMINI_API_KEY")
os.environ["groq_api_key"] = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### Google Gemini Model - Integration

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model("google_genai:gemini-2.0-flash")
response = model.invoke("What do parrots talk?")
response.content

# %%
"""method2: using ChatGoogleGenerativeAI"""

from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model = "gemini-2.0-flash")
response = model.invoke("What do parrots talk?")
response.content
# Out:
# 'method2: using ChatGoogleGenerativeAI'

# %% [markdown]
# ### GROQ model integraion

# %%
model = init_chat_model("groq:llama-3.3-70b-versatile")
response = model.invoke("Who is Shubman GIll?")
response.content
# Out:
# 'Shubman Gill is an Indian international cricketer who plays as a right-handed opening batsman. Born on September 8, 1999, in Fazilka, Punjab, India, Gill has quickly risen to prominence in the cricket world with his impressive performances.\n\nGill made his first-class debut for Punjab in 2017 and has since played for various teams, including the Indian Under-19 team, where he was the vice-captain of the team that reached the final of the 2018 ICC Under-19 Cricket World Cup.\n\nHe made his international debut for India in January 2019, playing in a One Day International (ODI) match against New Zealand. Since then, Gill has become a regular member of the Indian team, playing in various formats, including Tests, ODIs, and Twenty20 Internationals (T20Is).\n\nGill is known for his technical batting skills, ability to play long innings, and his impressive strokeplay. He has been praised by cricket experts and fans alike for his maturity and composure at the crease, which is rare for a pl
# ...

# %%
"""method2 : ChatGroq"""
from langchain_groq import ChatGroq

model = ChatGroq(
    model="llama-3.3-70b-versatile"
)
response = model.invoke("How Difficult was it to play Dale Steyn's OutSwingers?")
response.content
# Out:
# "Dale Steyn, a legendary South African fast bowler, was renowned for his ability to swing the ball both ways, but his outswingers were particularly challenging for batsmen to face. The difficulty of playing Steyn's outswingers can be attributed to several factors:\n\n1. **Late swing**: Steyn's outswingers would often swing late, making it difficult for batsmen to adjust their strokeplay. The ball would seem to be heading straight, only to swing away at the last moment, catching the batsman off guard.\n2. **Speed and bounce**: Steyn was a fast bowler, and his outswingers would often be delivered at a high pace (around 140-150 km/h). This made it harder for batsmen to react in time, as the ball would be on them quickly. The bounce he generated, especially on harder surfaces, would also make the ball climb onto the batsman, reducing the reaction time.\n3. **Accuracy and consistency**: Steyn was incredibly accurate, and his outswingers would often be delivered on a consistent line and le
# ...
